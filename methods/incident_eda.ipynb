# %%
# import necessary libraries
import pandas as pd
import sys
sys.path.append("/workspaces/acs-study/data")

# %%
filepath = '/workspaces/acs-study/data/ncjs/ncjs_2021_household.tsv'  #relative path to household-level data
df = pd.read_csv(filepath, sep='\t', header=0)  #raw dataframe
# Out:
# /tmp/ipykernel_45591/2898647747.py:2: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filepath, sep='\t', header=0)  #raw dataframe

# %%
df.head()
# Out:
#    V2001   YEARQ                       IDHH  V2002  V2003  V2004  \
# 0      2  2021.1  1710051325461935564934133      1    211     17
# 1      2  2021.1  1710051365368092564934132      2    211     17
# 2      2  2021.1  1710051365448275564934213      3    211     17
# 3      2  2021.1  1710051665447107564945132      4    211     17
# 4      2  2021.1  1710053925458004564944133      5    211     17
#
#                   V2005  V2006  V2008  V2009  ...  HHREPWGTCY151  \
# 0  10051325461935564934      1     33      0  ...        0.00000
# 1  10051365368092564934      1     32      0  ...     1141.30260
# 2  10051365448275564934      2     13      0  ...        0.00000
# 3  10051665447107564945      1     32      0  ...        0.00000
# 4  10053925458004564944      1     33      0  ...      644.90793
#
#    HHREPWGTCY152  HHREPWGTCY153  HHREPWGTCY154  HHREPWGTCY155  HHREPWGTCY156  \
# 0        0.00000        0.00000        0.00000        0.00000        0.00000
# ...
